# %%
import rmgpy
import numpy as np
from rmgpy.molecule.molecule import *
from rmgpy.species import *
from rmgpy.chemkin import *
from rmgpy.data.rmg import RMGDatabase
from IPython.display import display
from rmgpy.data.thermo import ThermoLibrary
from rmgpy.rmg.react import react
from rmgpy.species import Species
from rmgpy.reaction import Reaction
from rmgpy.data.rmg import get_db
from rmgpy.molecule.group import Group
from rmgpy.kinetics.arrhenius import ArrheniusBM
from rmgpy import settings
import time
import matplotlib.pyplot as plt
import matplotlib

# %%
settings
# Out:
# {'database.directory': '/home/khalil.nor/Code/RMG-database/input',
#  'test_data.directory': '/home/khalil.nor/Code/RMG-Py/rmgpy/test_data'}

# %%
thermo_libs = [
'C1_C2_Fluorine', #adding Siddha's as first most trusted because this is the thermo library that Franklin used
'PFCA_thermo',
'NCSU_C2_C8_PFAS', #adding Westmoreland's thermo as the second most trusted
'primaryThermoLibrary',
'Fluorine',
'FFCM1(-)',
'halogens',
'CHOF_G4',
'CHOCl_G4',
'CHOBr_G4',
'CHOFCl_G4',
'CHOFBr_G4',
'CHOFClBr_G4',
'DFT_QCI_thermo',
'2-BTP_G4',
'thermo_DFT_CCSDTF12_BAC',
'SulfurHaynes'
]

kin_families = ['XY_Addition_MultipleBond']

# %%
database = RMGDatabase()
database.load(
            path = settings['database.directory'],
            thermo_libraries = thermo_libs,
            transport_libraries = [],
            reaction_libraries = [],
            seed_mechanisms = [],#['BurkeH2O2inN2','ERC-FoundationFuelv0.9'],
            kinetics_families = kin_families,
            kinetics_depositories = ['training'],
            #frequenciesLibraries = self.statmechLibraries,
            depository = False, # Don't bother loading the depository information, as we don't use it
        )

# %%
database.kinetics.families
# Out:
# {'XY_Addition_MultipleBond': <ReactionFamily "XY_Addition_MultipleBond">}

# %%
# 'XY_Addition_MultipleBond' 
family_to_train = "XY_Addition_MultipleBond"
family = database.kinetics.families[family_to_train]

# %%
family.clean_tree()

# %%
start = time.time()
family.generate_tree(thermo_database=database.thermo,
                     nprocs=1,
                     new_fraction_threshold_to_reopt_node=0.25,
                     max_batch_size=800,
                     extension_iter_max=2,
                     extension_iter_item_cap=100)

end = time.time()
print(end-start)
# Out:
# ERROR:root:66.0
# ERROR:root:iter_max achieved terminating early
# ERROR:root:iter_max achieved terminating early
# ERROR:root:iter_max achieved terminating early
# ERROR:root:iter_max achieved terminating early
# ERROR:root:iter_max achieved terminating early
# 163.88757967948914

# %%
len(family.groups.entries)
# Out:
# 94

# %%
family.groups.entries
# Out:
# {'X_MultipleBond_Y': <Entry index=-1 label="X_MultipleBond_Y">,
#  'Root': <Entry index=0 label="Root">,
#  'Root_2Br1sCl1sF1sH->Cl1s': <Entry index=1 label="Root_2Br1sCl1sF1sH->Cl1s">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s': <Entry index=2 label="Root_N-2Br1sCl1sF1sH->Cl1s">,
#  'Root_2Br1sCl1sF1sH->Cl1s_1Br1sCl1sF1sH->Cl1s': <Entry index=3 label="Root_2Br1sCl1sF1sH->Cl1s_1Br1sCl1sF1sH->Cl1s">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s': <Entry index=4 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s': <Entry index=5 label="Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s': <Entry index=6 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd': <Entry index=7 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd': <Entry index=8 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_3COCdCddCtO2d->Ct': <Entry index=9 label="Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_3COCdCddCtO2d->Ct">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct': <Entry index=10 label="Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_3COCdCddCtO2d->O2d': <Entry index=11 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_3COCdCddCtO2d->O2d">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d': <Entry index=12 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R': <Entry index=13 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R': <Entry index=14 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd_Ext-3CtO2d-R': <Entry index=15 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd_Ext-3CtO2d-R">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R': <Entry index=16 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-3COCdO2d-R': <Entry index=17 label="Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-3COCdO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-4COCdCddCtO2d-R': <Entry index=18 label="Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_3COCdCddCtO2d->O2d_4COCdCddCtO2d->Cdd': <Entry index=19 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_3COCdCddCtO2d->O2d_4COCdCddCtO2d->Cdd">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_3COCdCddCtO2d->O2d_N-4COCdCddCtO2d->Cdd': <Entry index=20 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_3COCdCddCtO2d->O2d_N-4COCdCddCtO2d->Cdd">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H': <Entry index=21 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H': <Entry index=22 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_5R!H->Cl': <Entry index=23 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_5R!H->Cl">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_N-5R!H->Cl': <Entry index=24 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_N-5R!H->Cl">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R_Ext-4COCdCddCtO2d-R': <Entry index=25 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R_Ext-4COCdCddCtO2d-R">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R_5R!H->Cl': <Entry index=26 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R_5R!H->Cl">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R_N-5R!H->Cl': <Entry index=27 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R_N-5R!H->Cl">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd_Ext-3CtO2d-R_Ext-4COCdCddCtO2d-R': <Entry index=28 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd_Ext-3CtO2d-R_Ext-4COCdCddCtO2d-R">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R_3CtO2d->O2d': <Entry index=29 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R_3CtO2d->O2d">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R_N-3CtO2d->O2d': <Entry index=30 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_N-3COCdCddCtO2d->Cd_Ext-4COCdCddCtO2d-R_N-3CtO2d->O2d">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-3COCdO2d-R_5R!H->C': <Entry index=31 label="Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-3COCdO2d-R_5R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-3COCdO2d-R_N-5R!H->C': <Entry index=32 label="Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-3COCdO2d-R_N-5R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-4COCdCddCtO2d-R_3COCdO2d->O2d': <Entry index=33 label="Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-4COCdCddCtO2d-R_3COCdO2d->O2d">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-4COCdCddCtO2d-R_N-3COCdO2d->O2d': <Entry index=34 label="Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-4COCdCddCtO2d-R_N-3COCdO2d->O2d">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H': <Entry index=35 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H': <Entry index=36 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R': <Entry index=37 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R': <Entry index=38 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_3COCdCt->Cd': <Entry index=39 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_3COCdCt->Cd">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_N-3COCdCt->Cd': <Entry index=40 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_N-3COCdCt->Cd">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_5R!H->Cl_Ext-3Cd-R': <Entry index=41 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_5R!H->Cl_Ext-3Cd-R">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_5R!H->Cl_Ext-4COCdCddCtO2d-R': <Entry index=42 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_5R!H->Cl_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-3COCdO2d-R_N-5R!H->C_Ext-4COCdCddCtO2d-R_Ext-4COCdCddCtO2d-R': <Entry index=43 label="Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-3COCdO2d-R_N-5R!H->C_Ext-4COCdCddCtO2d-R_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-3COCdO2d-R_N-5R!H->C_Ext-3COCdO2d-R': <Entry index=44 label="Root_N-2Br1sCl1sF1sH->Cl1s_2Br1sF1sH->Br1s_N-3COCdCddCtO2d->Ct_Ext-3COCdO2d-R_N-5R!H->C_Ext-3COCdO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_3COCdCt->Cd': <Entry index=45 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_3COCdCt->Cd">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_N-3COCdCt->Cd': <Entry index=46 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_N-3COCdCt->Cd">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R': <Entry index=47 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_3COCdCt->Cd': <Entry index=48 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_3COCdCt->Cd">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_N-3COCdCt->Cd': <Entry index=49 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_N-3COCdCt->Cd">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O': <Entry index=50 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_N-5R!H->O': <Entry index=51 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_N-5R!H->O">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-5R!H-R': <Entry index=52 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-5R!H-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R': <Entry index=53 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_5R!H->Cl_Ext-3Cd-R_Ext-4COCdCddCtO2d-R': <Entry index=54 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_5R!H->Cl_Ext-3Cd-R_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R': <Entry index=55 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_N-3COCdCt->Cd_Ext-3COCt-R': <Entry index=56 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_N-3COCdCt->Cd_Ext-3COCt-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R': <Entry index=57 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_5R!H->C': <Entry index=58 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_5R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_N-5R!H->C': <Entry index=59 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_N-5R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R': <Entry index=60 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O_Ext-3COCdCt-R': <Entry index=61 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O_Ext-3COCdCt-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_N-5R!H->O_Ext-3COCdCt-R': <Entry index=62 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_N-5R!H->O_Ext-3COCdCt-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-5R!H-R_6R!H->C': <Entry index=63 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-5R!H-R_6R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-5R!H-R_N-6R!H->C': <Entry index=64 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-5R!H-R_N-6R!H->C">,
#  'Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_5R!H->Cl_Ext-3Cd-R_Ext-4COCdCddCtO2d-R_Ext-4COCdCddCtO2d-R': <Entry index=65 label="Root_2Br1sCl1sF1sH->Cl1s_N-1Br1sCl1sF1sH->Cl1s_3COCdCddCtO2d->Cd_Ext-3Cd-R_5R!H->Cl_Ext-3Cd-R_Ext-4COCdCddCtO2d-R_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_5R!H->C': <Entry index=66 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_5R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_N-5R!H->C': <Entry index=67 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_N-5R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_N-3COCdCt->Cd_Ext-3COCt-R_Ext-5R!H-R': <Entry index=68 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_N-3COCdCt->Cd_Ext-3COCt-R_Ext-5R!H-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R': <Entry index=69 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_5R!H->C_3COCdCt->Cd': <Entry index=70 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_5R!H->C_3COCdCt->Cd">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_5R!H->C_N-3COCdCt->Cd': <Entry index=71 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_5R!H->C_N-3COCdCt->Cd">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_N-5R!H->C_Ext-4COCdCddCtO2d-R': <Entry index=72 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_N-5R!H->C_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_5R!H->F': <Entry index=73 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_5R!H->F">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_N-5R!H->F': <Entry index=74 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_N-5R!H->F">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O_Ext-3COCdCt-R_Ext-5O-R_Ext-7R!H-R_Ext-5O-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_8R!H->C': <Entry index=75 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O_Ext-3COCdCt-R_Ext-5O-R_Ext-7R!H-R_Ext-5O-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_8R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O_Ext-3COCdCt-R_Ext-5O-R_Ext-7R!H-R_Ext-5O-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_N-8R!H->C': <Entry index=76 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O_Ext-3COCdCt-R_Ext-5O-R_Ext-7R!H-R_Ext-5O-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_N-8R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-5R!H-R_6R!H->C_Ext-6C-R_7R!H->C': <Entry index=77 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-5R!H-R_6R!H->C_Ext-6C-R_7R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-5R!H-R_6R!H->C_Ext-6C-R_N-7R!H->C': <Entry index=78 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-3COCdCt-R_Ext-5R!H-R_6R!H->C_Ext-6C-R_N-7R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_N-5R!H->C_Ext-5BrClFINOPSSi-R_Ext-6R!H-R': <Entry index=79 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_N-5R!H->C_Ext-5BrClFINOPSSi-R_Ext-6R!H-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_7R!H->C': <Entry index=80 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_7R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_N-7R!H->C': <Entry index=81 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_N-7R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_N-5R!H->C_Ext-4COCdCddCtO2d-R_6R!H->F': <Entry index=82 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_N-5R!H->C_Ext-4COCdCddCtO2d-R_6R!H->F">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_N-5R!H->C_Ext-4COCdCddCtO2d-R_N-6R!H->F': <Entry index=83 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_N-5R!H->C_Ext-4COCdCddCtO2d-R_N-6R!H->F">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_5R!H->F_Ext-4COCdCddCtO2d-R': <Entry index=84 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_3COCdCt->Cd_Ext-4COCdCddCtO2d-R_5R!H->F_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O_Ext-3COCdCt-R_Ext-5O-R_Ext-7R!H-R_Ext-5O-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_8R!H->C_Ext-8C-R_9R!H->C': <Entry index=85 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O_Ext-3COCdCt-R_Ext-5O-R_Ext-7R!H-R_Ext-5O-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_8R!H->C_Ext-8C-R_9R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O_Ext-3COCdCt-R_Ext-5O-R_Ext-7R!H-R_Ext-5O-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_8R!H->C_Ext-8C-R_N-9R!H->C': <Entry index=86 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_N-1Br1sCl1sF1sH->H_Ext-4COCdCddCtO2d-R_5R!H->O_Ext-3COCdCt-R_Ext-5O-R_Ext-7R!H-R_Ext-5O-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_Ext-8R!H-R_Ext-5O-R_8R!H->C_Ext-8C-R_N-9R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_7R!H->C_Ext-7C-R_8R!H->C': <Entry index=87 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_7R!H->C_Ext-7C-R_8R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_7R!H->C_Ext-7C-R_N-8R!H->C': <Entry index=88 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_7R!H->C_Ext-7C-R_N-8R!H->C">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_N-7R!H->C_7BrClFINOPSSi->F': <Entry index=89 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_N-7R!H->C_7BrClFINOPSSi->F">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_N-7R!H->C_N-7BrClFINOPSSi->F': <Entry index=90 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_N-7R!H->C_N-7BrClFINOPSSi->F">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_N-5R!H->C_Ext-4COCdCddCtO2d-R_6R!H->F_Ext-4COCdCddCtO2d-R': <Entry index=91 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_N-5R!H->C_Ext-4COCdCddCtO2d-R_6R!H->F_Ext-4COCdCddCtO2d-R">,
#  'Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_N-7R!H->C_7BrClFINOPSSi->F_Ext-4COCdCddCtO2d-R': <Entry index=92 label="Root_N-2Br1sCl1sF1sH->Cl1s_N-2Br1sF1sH->Br1s_N-3COCdCddCtO2d->O2d_1Br1sCl1sF1sH->H_N-2F1sH->H_Ext-3COCdCt-R_Ext-3COCdCt-R_Ext-4COCdCddCtO2d-R_N-7R!H->C_7BrClFINOPSSi->F_Ext-4COCdCddCtO2d-R">}

# %%
start = time.time()
family.check_tree()
end = time.time()
print(end-start)
# Out:
# 0.016587495803833008

# %%
start = time.time()
family.regularize(thermo_database=database.thermo)
end = time.time()
print(end-start)
# Out:
# 0.8023529052734375

# %%
start = time.time()
templateRxnMap = family.get_reaction_matches(thermo_database=database.thermo,remove_degeneracy=True,
                                             get_reverse=True,exact_matches_only=False,fix_labels=True)
end = time.time()
print(end-start)
# Out:
# 0.7126617431640625

# %%
len(templateRxnMap)
# Out:
# 94

# %%
family.clean_tree_rules()

# %%
start = time.time()
family.make_bm_rules_from_template_rxn_map(templateRxnMap)#,nprocs=6)
end = time.time()
print(end-start)
# Out:
# /home/khalil.nor/Code/RMG-Py/rmgpy/data/kinetics/family.py:3624: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   for rxns, label in rxnlists])
# position 1, 0.0
# term 1: 147446.9775896396, term 2: 19377.218106021544
# position 2: 166824.19569566115
# term 1: 144378.0, term 2: -17044.439075303366
# position 2: 294157.7566203578
# position 3: 147078.8783101789
# position 4: 147078.8783101789
# position 6: 131106.71471733775
# position 9: 131106.71471733775
# position 10: 131106.71471733775
# position 1, 0.0
# term 1: 144378.0, term 2: -17044.439075303366
# position 2: 127333.56092469663
# position 3: 127333.56092469663
# position 4: 127333.56092469663
# position 6: 107272.50950971687
# position 9: 107272.50950971687
# position 10: 107272.50950971687
# position 1, 0.0
# term 1: 147446.9775896396, term 2: 19377.218106021544
# position 2:
# term 1: 147996.71724335925, term 2: 17648.130797521924
# position 2: 4809997.305319487
# term 1: 223345.47611320016, term 2: 10942.827711979
# position 2: 5044285.609144666
# term 1: 144378.0, term 2: -17044.439075303366
# position 2: 5171619.170069363
# term 1: 163976.0, term 2: -13311.621563183726
# position 2: 5322283.548506179
# term 1: 114076.27628644224, term 2: 7725.062629511958
# position 2: 5444084.887422133
# term 1: 119447.65159581772, term 2: 41616.687888946966
# position 2: 5605149.2269068975
# term 1: 138910.7505759344, term 2: 659.8158032114734
# position 2: 5744719.793286043
# term 1: 164886.49525095432, term 2: 16196.731740874646
# position 2: 5925803.020277872
# term 1: 153763.09296954732, term 2: -3773.0766159399645
# position 2: 6075793.036631479
# term 1: 114264.03056011122, term 2: 39963.32398214983
# position 2: 6230020.39117374
# term 1: 175874.74499827015, term 2: 11281.342337360664
# position 2: 6417176.478509371
# term 1: 145932.98447143607, term 2: 32526.312537938822
# position 2: 6595635.775518746
# term 1: 146512.88687143626, term 2: 32526.312537938706
# position 2: 6774674.974928121
# term 1: 127720.6129033604, term 2: 12998.614540203649
# position 2: 6915394.202371685
# term 1: 145538.92919491106, term 2: 9720.596205097347
# position 2: 7070653.727771693
# term 1: 95793.07962932158, term 2: 10859.793017916236

# %%
start = time.time()
family.check_tree()
end = time.time()
print(end-start)

# %%
start = time.time()
errors,uncertainties = family.cross_validate(iters=0,random_state=5,folds=0,ascend=False)
end = time.time()
print(end-start)

# %%
save_path = os.path.join(settings['database.directory'], 'kinetics', 'families', family.name)
print(save_path)

# %%
family.save(save_path)

# %%
#also save to this folder 
save_here = '.'
family.save(save_here)

# %%
# notebook ran to completion for third retraining on Sep 18th 2024, 3:07 pm

# %%
#let's check to see what the fit is like at the end nodes

# %%
from rmgpy.kinetics.uncertainties import RateUncertainty
import rmgpy
import numpy as np
from rmgpy.molecule.molecule import *
from rmgpy.species import *
from rmgpy.chemkin import *
from rmgpy.data.rmg import RMGDatabase
from IPython.display import display
from rmgpy.data.thermo import ThermoLibrary
from rmgpy.rmg.react import react
from rmgpy.species import Species
from rmgpy.reaction import Reaction
from rmgpy.data.rmg import get_db
from rmgpy.molecule.group import Group
from rmgpy.kinetics.arrhenius import ArrheniusBM, Arrhenius
from rmgpy import settings
import time
import matplotlib.pyplot as plt
import matplotlib
import rmgpy.constants as constants

# %%
thermo_libs = [
'C1_C2_Fluorine', #adding Siddha's as first most trusted because this is the thermo library that Franklin used
'PFCA_thermo',
'NCSU_C2_C8_PFAS', #adding Westmoreland's thermo as the second most trusted
'primaryThermoLibrary',
'Fluorine',
'FFCM1(-)',
'halogens',
'CHOF_G4',
'CHOCl_G4',
'CHOBr_G4',
'CHOFCl_G4',
'CHOFBr_G4',
'CHOFClBr_G4',
'DFT_QCI_thermo',
'2-BTP_G4',
'thermo_DFT_CCSDTF12_BAC',
'SulfurHaynes'
]

kin_families = ["Lactone_Formation"]

database = RMGDatabase()
database.load(
            path = settings['database.directory'],
            thermo_libraries = thermo_libs,
            transport_libraries = [],
            reaction_libraries = [],
            seed_mechanisms = [],#['BurkeH2O2inN2','ERC-FoundationFuelv0.9'],
            kinetics_families = kin_families,
            kinetics_depositories = ['training'],
            #frequenciesLibraries = self.statmechLibraries,
            depository = False, # Don't bother loading the depository information, as we don't use it
        )

# %%
database.kinetics.families

# %%
# "1,2_Insertion_carbene"
family_to_train = "Lactone_Formation"
family = database.kinetics.families[family_to_train]

# %%
start = time.time()
templateRxnMap = family.get_reaction_matches(thermo_database=database.thermo,remove_degeneracy=True,
                                             get_reverse=True,exact_matches_only=False,fix_labels=True)
end = time.time()
print(end-start)

# %%
Let's look at some of the parent nodes (with 2 reactions) and their child nodes (with 1 reaction) to see how the fits compare

# %%
n_2_mapping = [key for key, value in templateRxnMap.items() if len(value)==2] #mapping of all nodes with 3 or less training rxns (parents)
n_1_mapping = [key for key, value in templateRxnMap.items() if len(value)==1] #mapping of all nodes with 1 training rxn (children)
n_4_mapping = [key for key, value in templateRxnMap.items() if len(value)==4] 
parent_to_child = {}
parent_to_child_4 = {}

for label in n_2_mapping: 
    
    #make the parent node
    parent_node, _ = family.retrieve_original_entry(label)
    
    #now find the children with just 1 reaction
    children_nodes = []
    for test_label in n_1_mapping:
        if label in test_label:
            child_node, _ = family.retrieve_original_entry(test_label)
            children_nodes.append(child_node)
            
            
    if len(templateRxnMap[label])==len(children_nodes): #let's pick out the ones that are both two
        parent_to_child[parent_node.label] = [x.label for x in children_nodes]
        
for label in n_4_mapping: 
    
    #make the parent node
    parent_node, _ = family.retrieve_original_entry(label)
    
    #now find the children with just 1 reaction
    children_nodes = []
    for test_label in n_1_mapping:
        if label in test_label:
            child_node, _ = family.retrieve_original_entry(test_label)
            children_nodes.append(child_node)
            
            
    if len(templateRxnMap[label])==len(children_nodes): #let's pick out the ones that are both two
        parent_to_child_4[parent_node.label] = [x.label for x in children_nodes]
#parent_to_child is a dictionary where key = label of parent and value = label of children

# %%
# %matplotlib inline
temperatures = [ 300., 500.,  600.,  700. , 800.,  900., 1000., 1100., 1200., 1500., 2000.]
inverse_temps = [1000/T for T in temperatures]



for parent_label, children_labels in parent_to_child.items():
    
    training_rxns = templateRxnMap[parent_label] 
    for tr_rxn in training_rxns:
        print(tr_rxn)
    BM_entries = [family.retrieve_original_entry(label)[0].data for label in children_labels]

    matches = []
    matched_BM = []

    for BM_kinetics in BM_entries:
        for tr_rxn in training_rxns:
            BM_str_of_float = re.search('([1-9]\.?[0-9][0-9])', str(BM_kinetics.A.value_si)).group(1)
            tr_str_of_float = re.search('([1-9]\.?[0-9][0-9])', str(tr_rxn.kinetics.A.value_si)).group(1)
            if BM_str_of_float==tr_str_of_float:
                #print('yeah')
                matches.append((Reaction(reactants=tr_rxn.reactants, products=tr_rxn.products, kinetics = BM_kinetics), tr_rxn))
                matched_BM.append(BM_kinetics)
    if len(matches)==0:
        print("couldn't find any matches")
        continue
        #skipping because the A's are probably very different
        
    #if you miss matching all of them
    if len(matches)==1:
        leftover_tr_rxn = [tr_rxn for tr_rxn in training_rxns if tr_rxn not in matches[0]][0]
        leftover_BM_kinetics = [BM_kinetics for BM_kinetics in BM_entries if BM_kinetics not in matched_BM][0]
        leftover_BM_reaction = Reaction(reactants=leftover_tr_rxn.reactants, products=leftover_tr_rxn.products, kinetics = leftover_BM_kinetics)
        #print(leftover_BM_reaction.kinetics.A, leftover_tr_rxn.kinetics.A)
        matches.append((leftover_BM_reaction, leftover_tr_rxn))

#     for (BM, tr) in matches: 
#         print(str(BM.kinetics.A.value_si), str(tr.kinetics.A.value_si))
        
    child_node_1_BM_rxn, child_training_rxn_1= matches[0] 
    child_node_2_BM_rxn, child_training_rxn_2 = matches[1] 
    
    #empty lists for collecting data
    parent_node_rate_coefficients_1 = []
    parent_node_rate_coefficients_2 = []

    child_node_1_rate_coefficients = []
    child_node_2_rate_coefficients = []

    child_tr_rxn_coeffs_1 = []
    child_tr_rxn_coeffs_2 = []
    
    #let's make the parent BM node
    parent_node, _ = family.retrieve_original_entry(parent_label)
    BM_parent_rxn = Reaction(kinetics = parent_node.data)

    
    #get the dHrxns 
    
    dHrxn_1 = child_node_1_BM_rxn.get_enthalpy_of_reaction(298)
    dHrxn_2 = child_node_2_BM_rxn.get_enthalpy_of_reaction(298)

    
    for temp in temperatures: 
        
        #calculate training rxn rate
        tr_rate_1 = child_training_rxn_1.kinetics.get_rate_coefficient(temp) #J/mol #loaded in as Arr training rxn from templateRxnMap
        tr_rate_2 =child_training_rxn_2.kinetics.get_rate_coefficient(temp) #J/mol #loaded in as Arr training rxn from templateRxnMap

        child_tr_rxn_coeffs_1.append(tr_rate_1)
        child_tr_rxn_coeffs_2.append(tr_rate_2)
        
        #calculate BM child rates
        BM_child_rate_1 = child_node_1_BM_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_1) #loaded in as BM kinetics 
        BM_child_rate_2 = child_node_2_BM_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_2) #loaded in as BM kinetics 

        child_node_1_rate_coefficients.append(BM_child_rate_1)
        child_node_2_rate_coefficients.append(BM_child_rate_2)
        
        #calculate BM for parent node at both dHrxns for child rxns
        BM_parent_node_rate_dH1 = BM_parent_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_1)
        parent_node_rate_coefficients_1.append(BM_parent_node_rate_dH1)
        BM_parent_node_rate_dH2 = BM_parent_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_2)
        parent_node_rate_coefficients_2.append(BM_parent_node_rate_dH2)
        
    
    #get lnks

    parent_node_1 = [np.log(rate) for rate in parent_node_rate_coefficients_1]
    parent_node_2 = [np.log(rate) for rate in parent_node_rate_coefficients_2]
    child_node_1 = [np.log(rate) for rate in child_node_1_rate_coefficients]  
    child_node_2 = [np.log(rate) for rate in child_node_2_rate_coefficients]
    child_tr_1 = [np.log(rate) for rate in child_tr_rxn_coeffs_1]
    child_tr_2 = [np.log(rate) for rate in child_tr_rxn_coeffs_2]


    print(child_node_1_BM_rxn.kinetics.A, child_training_rxn_1.kinetics.A)
    #plotting
    plt.figure()   
    plt.plot(inverse_temps, child_node_1, '-', c= 'r', label = 'child BM rxn 1')
    plt.plot(inverse_temps, child_node_2, '-', c= 'g', label = 'child BM rxn 2')
    plt.plot(inverse_temps, child_tr_1, 'o', c='r', label='child training rxn 1')
    plt.plot(inverse_temps, child_tr_2, 'o', c='g', label='child training rxn 2')
    plt.plot(inverse_temps, parent_node_1, ':', c='r', label = 'parent BM fit 1')   
    plt.plot(inverse_temps, parent_node_2, ':', c='g', label = 'parent BM fit 2')   


    plt.title(parent_label)
    plt.xlabel('1000/T')
    plt.ylabel('ln(k)')
    plt.legend()
    plt.show()

# %%
#n = 4, node with 4 reactions
# %matplotlib inline
temperatures = [ 300., 500.,  600.,  700. , 800.,  900., 1000., 1100., 1200., 1500., 2000.]
inverse_temps = [1000/T for T in temperatures]



for parent_label, children_labels in parent_to_child_4.items():
    
    training_rxns = templateRxnMap[parent_label] 
    for tr_rxn in training_rxns:
        print(tr_rxn)
    BM_entries = [family.retrieve_original_entry(label)[0].data for label in children_labels]

    
    matches = []
    matched_BM = []
    matched_tr = []

    for BM_kinetics in BM_entries:
        for tr_rxn in training_rxns:
            BM_str_of_float = re.search('([1-9]\.?[0-9][0-9])', str(BM_kinetics.A.value_si)).group(1)
            tr_str_of_float = re.search('([1-9]\.?[0-9][0-9])', str(tr_rxn.kinetics.A.value_si)).group(1)
            if BM_str_of_float==tr_str_of_float:
                print('yeah')
                matches.append((Reaction(reactants=tr_rxn.reactants, products=tr_rxn.products, kinetics = BM_kinetics), tr_rxn))
                matched_BM.append(BM_kinetics)
                matched_tr.append(tr_rxn)
                
    if len(matches)==0:
        print("couldn't find any matches")
        continue
        #skipping because the A's are probably very different
        
    for (BM, tr) in matches:
        print(BM.kinetics.A.value_si, tr.kinetics.A.value_si)
        
#     if 0<len(matches)<len(training_rxns) and len(BM_entries)==len(training_rxns):
#         leftover_tr_rxns = [tr_rxn for tr_rxn in training_rxns if tr_rxn not in matched_tr]
#         leftover_BM_kinetics = [BM_kinetics for BM_kinetics in BM_entries if BM_kinetics not in matched_BM]
#         for leftover_tr_rxn in leftover_tr_rxns:
#             for leftover_BM_kinetics in leftover_BM_kinetics_:
#                 if re.search('([1-9]\.?[0-9][0-9])', str(leftover_BM_kinetics)).group(1)==re.search('([1-9]\.?[0-9][0-9])', str(leftover_tr_rxn.kinetics.A.value_si)).group(1):
#                     leftover_BM_reaction = Reaction(reactants=leftover_tr_rxn.reactants, products=leftover_tr_rxn.products, kinetics = leftover_BM_kinetics)
#                     print(leftover_BM_reaction.kinetics.A, leftover_tr_rxn.kinetics.A)
#                     matches.append((leftover_BM_reaction, leftover_tr_rxn))

    if len(BM_entries)!=len(matches):
        flag=False
    else:
        flag=True

    child_node_1_BM_rxn, child_training_rxn_1= matches[0] 
    child_node_2_BM_rxn, child_training_rxn_2 = matches[1] 
    child_node_3_BM_rxn, child_training_rxn_3= matches[2]
    if flag==True: 
        child_node_4_BM_rxn, child_training_rxn_4 = matches[3] 
    
    #empty lists for collecting data
    parent_node_rate_coefficients_1 = []
    parent_node_rate_coefficients_2 = []
    parent_node_rate_coefficients_3 = []
    parent_node_rate_coefficients_4 = []

    child_node_1_rate_coefficients = []
    child_node_2_rate_coefficients = []
    child_node_3_rate_coefficients = []
    child_node_4_rate_coefficients = []

    child_tr_rxn_coeffs_1 = []
    child_tr_rxn_coeffs_2 = []
    child_tr_rxn_coeffs_3 = []
    child_tr_rxn_coeffs_4 = []
    
    #let's make the parent BM node
    parent_node, _ = family.retrieve_original_entry(parent_label)
    BM_parent_rxn = Reaction(kinetics = parent_node.data)

    
    #get the dHrxns 
    
    dHrxn_1 = child_node_1_BM_rxn.get_enthalpy_of_reaction(298)
    dHrxn_2 = child_node_2_BM_rxn.get_enthalpy_of_reaction(298)
    dHrxn_3 = child_node_3_BM_rxn.get_enthalpy_of_reaction(298)
    if flag==True: 
        dHrxn_4 = child_node_4_BM_rxn.get_enthalpy_of_reaction(298)

    
    for temp in temperatures: 
        
        #calculate training rxn rate
        tr_rate_1 = child_training_rxn_1.kinetics.get_rate_coefficient(temp) #J/mol #loaded in as Arr training rxn from templateRxnMap
        tr_rate_2 =child_training_rxn_2.kinetics.get_rate_coefficient(temp) #J/mol #loaded in as Arr training rxn from templateRxnMap
        tr_rate_3 = child_training_rxn_3.kinetics.get_rate_coefficient(temp) #J/mol #loaded in as Arr training rxn from templateRxnMap
        if flag==True: 
            tr_rate_4 =child_training_rxn_4.kinetics.get_rate_coefficient(temp) #J/mol #loaded in as Arr training rxn from templateRxnMap

        child_tr_rxn_coeffs_1.append(tr_rate_1)
        child_tr_rxn_coeffs_2.append(tr_rate_2)
        child_tr_rxn_coeffs_3.append(tr_rate_3)
        if flag==True:
            child_tr_rxn_coeffs_4.append(tr_rate_4)
        
        #calculate BM child rates
        BM_child_rate_1 = child_node_1_BM_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_1) #loaded in as BM kinetics 
        BM_child_rate_2 = child_node_2_BM_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_2) #loaded in as BM kinetics 
        BM_child_rate_3 = child_node_3_BM_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_3) #loaded in as BM kinetics 
        if flag==True:
            BM_child_rate_4 = child_node_4_BM_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_4) #loaded in as BM kinetics 

        child_node_1_rate_coefficients.append(BM_child_rate_1)
        child_node_2_rate_coefficients.append(BM_child_rate_2)
        child_node_3_rate_coefficients.append(BM_child_rate_3)
        if flag==True:
            child_node_4_rate_coefficients.append(BM_child_rate_4)
        
        #calculate BM for parent node at both dHrxns for child rxns
        BM_parent_node_rate_dH1 = BM_parent_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_1)
        parent_node_rate_coefficients_1.append(BM_parent_node_rate_dH1)
        BM_parent_node_rate_dH2 = BM_parent_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_2)
        parent_node_rate_coefficients_2.append(BM_parent_node_rate_dH2)
        BM_parent_node_rate_dH3 = BM_parent_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_3)
        parent_node_rate_coefficients_3.append(BM_parent_node_rate_dH3)
        if flag==True:
            BM_parent_node_rate_dH4 = BM_parent_rxn.kinetics.get_rate_coefficient(temp, dHrxn=dHrxn_4)
            parent_node_rate_coefficients_4.append(BM_parent_node_rate_dH4)
        
    
    #get lnks

    parent_node_1 = [np.log(rate) for rate in parent_node_rate_coefficients_1]
    parent_node_2 = [np.log(rate) for rate in parent_node_rate_coefficients_2]
    parent_node_3 = [np.log(rate) for rate in parent_node_rate_coefficients_3]
    if flag==True:
        parent_node_4 = [np.log(rate) for rate in parent_node_rate_coefficients_4]
    
    child_node_1 = [np.log(rate) for rate in child_node_1_rate_coefficients]  
    child_node_2 = [np.log(rate) for rate in child_node_2_rate_coefficients]
    child_node_3 = [np.log(rate) for rate in child_node_3_rate_coefficients]  
    if flag==True:
        child_node_4 = [np.log(rate) for rate in child_node_4_rate_coefficients]
    
    child_tr_1 = [np.log(rate) for rate in child_tr_rxn_coeffs_1]
    child_tr_2 = [np.log(rate) for rate in child_tr_rxn_coeffs_2]
    child_tr_3 = [np.log(rate) for rate in child_tr_rxn_coeffs_3]
    if flag==True:
        child_tr_4 = [np.log(rate) for rate in child_tr_rxn_coeffs_4]


    print(child_node_1_BM_rxn.kinetics.A, child_training_rxn_1.kinetics.A)
    #plotting
    plt.figure()   
    plt.plot(inverse_temps, child_node_1, '-', c= 'r', label = 'child BM rxn 1')
    plt.plot(inverse_temps, child_node_2, '-', c= 'g', label = 'child BM rxn 2')
    plt.plot(inverse_temps, child_node_3, '-', c= 'violet', label = 'child BM rxn 3')
    if flag==True:
        plt.plot(inverse_temps, child_node_4, '-', c= 'b', label = 'child BM rxn 4')
    
    plt.plot(inverse_temps, child_tr_1, 'o', c='r', label='child training rxn 1')
    plt.plot(inverse_temps, child_tr_2, 'o', c='g', label='child training rxn 2')
    plt.plot(inverse_temps, child_tr_3, 'o', c='violet', label='child training rxn 3')
    if flag==True:
        plt.plot(inverse_temps, child_tr_4, 'o', c='b', label='child training rxn 4')
    
    plt.plot(inverse_temps, parent_node_1, ':', c='r', label = 'parent BM fit 1')   
    plt.plot(inverse_temps, parent_node_2, ':', c='g', label = 'parent BM fit 2')
    plt.plot(inverse_temps, parent_node_3, ':', c='violet', label = 'parent BM fit 3')   
    if flag==True:
        plt.plot(inverse_temps, parent_node_4, ':', c='b', label = 'parent BM fit 4')


    plt.title(parent_label)
    plt.xlabel('1000/T')
    plt.ylabel('ln(k)')
    plt.legend(loc=(1.1,0.8))
    plt.show()
