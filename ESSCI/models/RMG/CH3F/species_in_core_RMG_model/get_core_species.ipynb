# %%
import matplotlib.pylab as plt
import numpy as np
import re
import os
import csv
import pandas as pd
import matplotlib
import copy
import cantera as ct
from rmgpy.chemkin import load_chemkin_file
# %matplotlib inline

# %%
#preliminary CH3F

path_chemkin='/work/westgroup/nora/Code/projects/halogens/refrigerants/singles/CH3F/chemkin/chem_annotated.inp'
species_dictionary='/work/westgroup/nora/Code/projects/halogens/refrigerants/singles/CH3F/chemkin/species_dictionary.txt'
transport_path='/work/westgroup/nora/Code/projects/halogens/refrigerants/singles/CH3F/chemkin/tran.dat'

spec_RMG, reac_RMG = load_chemkin_file(path_chemkin, dictionary_path=species_dictionary, transport_path=transport_path )

# %%
for spec in spec_RMG:
    print(spec)
# Out:
# N2
# Ne
# CH3F(1)
# O2(2)
# H2O(3)
# CH4(4)
# H(5)
# O(6)
# OH(7)
# H2(8)
# Ar(9)
# He(10)
# HO2(11)
# H2O2(12)
# CO(13)
# CO2(14)
# HCO(15)
# C(T)(16)
# CH(17)
# CH2(T)(18)
# CH3(19)
# CH2O(20)
# HCCO(21)
# C2H(22)
# C2H2(23)
# H2CC(24)
# CH2(S)(25)
# CH3OH(26)
# CH3O(27)
# CH2CO(28)
# C2H3(29)
# C2H4(30)
# C2H6(31)
# C2H5(32)
# CH2OH(33)
# CH3CO(34)
# CH2CHO(35)
# CH3CHO(36)
# F(37)
# HF(38)
# CHF(39)
# CH2F2(40)
# CHF3(41)
# CF2(42)
# CF3(44)
# CH2F(45)
# CHFO(46)
# CF3O(47)
# CF2O(48)
# CF(49)
# CFO(50)
# CH2CHF(55)
# CH2F-CH2(61)
# CH3-CHF(62)
# CH2CF(69)
# CHFCH[Z](70)
# CH2CFO(78)
# CHF2(81)
# [O]OF(124)
# O=O(128)
# [O]CF(131)
# OF(133)
# [O]OCF(139)
# O=[C]O(145)
# [O]C=O(146)
# [O]C(=O)F(148)
# C1OO1(156)
# [O]C[O](158)
# O=CO(160)
# [O]C([O])F(165)
# [CH]=C[O](181)
# FC1OO1(186)
# [O]C(F)F(189)
# O=C(O)F(220)
# [O]C(O)(F)F(290)
# [O]OC(=O)F(296)
# [O]C(=O)O(309)
# FC1CO1(564)
# [O]C1(F)OO1(1309)
# [O]OC(F)F(2051)
# O[C](F)F(2111)
# OC(F)(F)F(2239)
# [O]OC(F)(F)F(2608)

# %%
already_there = ['CH3F',
'O2',
'H2O',
'N2',
'CH4',
'Ne']

for spec in spec_RMG:
    if spec.label not in already_there:
        print(f'''
species(
    label = '{spec}',
    reactive = True,
    structure = SMILES('{spec.smiles}')
)
    
''')
# Out:
# species(
#     label = 'H(5)',
#     reactive = True,
#     structure = SMILES('[H]')
# )
#
#
#
# species(
#     label = 'O(6)',
#     reactive = True,
#     structure = SMILES('[O]')
# )
#
#
#
# species(
#     label = 'OH(7)',
#     reactive = True,
#     structure = SMILES('[OH]')
# )
#
#
#
# species(
#     label = 'H2(8)',
#     reactive = True,
#     structure = SMILES('[H][H]')
# )
#
#
#
# species(
#     label = 'Ar(9)',
#     reactive = True,
#     structure = SMILES('[Ar]')
# )
#
#
#
# species(
#     label = 'He(10)',
#     reactive = True,
#     structure = SMILES('[He]')
# )
#
#
#
# species(
#     label = 'HO2(11)',
#     reactive = True,
#     structure = SMILES('[O]O')
# )
#
#
#
# species(
#     label = 'H2O2(12)',
#     reactive = True,
#     structure = SMILES('OO')
# )
#
#
#
# species(
#     label = 'CO(13)',
#     reactive = True,
#     structure = SMILES('[C-]#[O+]')
# )
#
#
#
# species(
#     label = 'CO2(14)',
#     reactive = True,
# ...
