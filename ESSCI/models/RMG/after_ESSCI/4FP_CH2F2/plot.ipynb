# %%
import numpy as np
import matplotlib.pylab as plt
import matplotlib
import os 
import re
import pandas as pd
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

# %matplotlib inline

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 12}

matplotlib.rc('font', **font)
matplotlib.rc('lines', linewidth=1.8, color='black')

fontdict={'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}

# %% [markdown]
# Experimental

# %%
#experimental

empty_boxes_x = [0.09955947136563881,0.2,0.30044052863436127,0]
empty_boxes_y=[4.829218317795309,3.7749206023972963,2.813646142813237,6.651060342178055]

filled_diamond_x= [0.2925110132158591,0.4973568281938326]
filled_diamond_y= [2.2793771130007165, 1.7518696854830438]


filled_circle_x=[0.48149779735682824,0.6969162995594715,0.9995594713656388,0.9982378854625553]
filled_circle_y=[1.7996106956254465,1.4108185636717536,1.131543899190655,1.480483557012601]

# %% [markdown]
# before re-training

# %%
old_fracs=[0.0,0.041666666666666664,0.08333333333333333,0.125,0.16666666666666666,0.20833333333333331,0.25,0.29166666666666663,0.3333333333333333,0.375,0.41666666666666663,0.4583333333333333,0.5,0.5416666666666666,0.5833333333333333,0.625,0.6666666666666666,0.7083333333333333,0.75,0.7916666666666666,0.8333333333333333,0.875,0.9166666666666666,0.9583333333333333,1.0]
s=[0.08122938707269423,0.06935301086775858,0.06077268200029748,0.05315471388025811,0.048116852974357215,0.04440770917381328,0.04232809851960856,0.04042623202002145,0.039155868187248526,0.03827817735376345,0.0377168278088061,0.03739139240666798,0.03724486663834482,0.037243170867836815,0.03733150790257921,0.03748353083415602,0.03721160613984474,0.03740730292929049,0.037594533410692355,0.03774093647695426,0.037849103275402356,0.03792411879238611,0.038513142069244596,0.03863969351876689,0.03898441100808147]
old_spds=np.array(s)*100

# %% [markdown]
# After re-training

# %%
#this was right before presentation at ESSCI
new_fracs= [0.0,0.041666666666666664,0.08333333333333333,0.125,0.16666666666666666,0.20833333333333331,0.25, 0.29166666666666663,0.3333333333333333,0.375,0.41666666666666663,0.4583333333333333,0.5,0.5416666666666666,0.5833333333333333,0.625,0.6666666666666666,0.7083333333333333,0.75,0.7916666666666666,0.8333333333333333,0.875,0.9166666666666666,0.9583333333333333,1.0]
speeds = [0.08455819923429932,0.07094719659002692,0.06060672594295157,0.052829832849782425,0.04562545211478723,0.03924735441337028,0.03456617382499533,0.029840356714592103,0.026676157242421172,0.023906640572362144,0.022083621135468044,0.020832932994286704,0.020045683180593132,0.019606952518666083,0.019367074240913027,0.019340223640355723,0.01945221283154747,0.01967386654077716,0.020007046703528538,0.02042879385148781,0.02092218651215631,0.021454335443440123,0.02207880722558595,0.022705275480639147,0.02339073266875773]
new_spds = np.array(speeds)

# %% [markdown]
# after re-training again following ESSCI

# %%
speeds_1 = [0.07143884743397617,0.07441042260458026,0.07824450184879517,0.08285054665658008,0.0869526322955659,0.09123742700503273,0.09481180637677993]
speeds_2 = [0.09775244285588386,0.10067314562621732,0.10339457401484274,0.10571438911163135,0.10783043482232105,0.10967295442716654]
speeds_3 = [0.1113714440321351,0.11272504366564672,0.11388336816522468,0.11508084624977229,0.11605034999687563,0.11707994064818526]
speeds_4 = [0.11779969795784802,0.1187211804008774,0.11912342747657051,0.11961826630958854,0.12027337336086985,0.12071010602089088]
new_speeds_after_essci = np.array(speeds_1+speeds_2+speeds_3+speeds_4)

frac_1 = [0.0,0.041666666666666664,0.08333333333333333,0.125,0.16666666666666666,0.20833333333333331,0.25]
frac_2 = [0.29166666666666663,0.3333333333333333,0.375,0.41666666666666663,0.4583333333333333,0.5]
frac_3 = [0.5416666666666666,0.5833333333333333,0.625,0.6666666666666666,0.7083333333333333,0.75]
frac_4 = [0.7916666666666666,0.8333333333333333,0.875,0.9166666666666666,0.9583333333333333,1.0]
fracs_after_essci = frac_1+frac_2+frac_3+frac_4

# %%
#PLOTTING SECTION
plt.rcParams['figure.figsize'] = (7,6)
plt.rcParams['axes.labelsize'] = 22
plt.rcParams['xtick.labelsize'] = 22
plt.rcParams['ytick.labelsize'] = 22
plt.rcParams['figure.autolayout'] = True
matplotlib.rcParams['font.family'] = 'serif'

# %%
matplotlib.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
#           'axes.grid': False,
# ...

# %%
#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111) 

ax1.plot(old_fracs, old_spds, '--', c='black', linewidth = 3, label='preliminary' )
ax1.plot(new_fracs, new_spds*100, ':', c='black',linewidth = 3, label='new, before ESSCI' )
ax1.plot(fracs_after_essci, new_speeds_after_essci*100, '-', c='black',linewidth = 3, label='new, after ESSCI' )


ax1.plot(empty_boxes_x, empty_boxes_y, '*', c='black', markersize=15 )
ax1.plot(filled_diamond_x, filled_diamond_y, 'o', c='black', markersize=15 )
ax1.plot(filled_circle_x, filled_circle_y, 'x', c='black', markersize=15 )
listOf_Yticks = np.arange(0, 12, 2)
plt.yticks(listOf_Yticks)

plt.xlabel(r'$CH_{2}=CFCF_{3}$ Mole Fraction')
plt.ylabel(r'$S_{L}$ (cm/s)')
plt.title('2,3,3,3-tetrafluoropropene / difluoromethane', fontsize=16)
ax1.legend(loc ='best', fontsize=15)
